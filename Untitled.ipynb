# %%
import networkx

# %%
G = networkx.Graph()

# %%
G.add_node(1)
G.add_node(2)
G.add_node(3)
G.add_node(4)
G.add_node(5)

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5))

# %%
G.add_edge(1,2)

# %%
G.add_edge(2,3)
G.add_edge(3,4)
G.add_edge(4,5)

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (2, 3), (3, 4), (4, 5)])

# %%
G.add_edge(1,6)

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 6), (2, 3), (3, 4), (4, 5)])

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
G.networkx.Graph()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-4883fb35ff0b> in <module>
# ----> 1 G.networkx.Graph()
#
# AttributeError: 'Graph' object has no attribute 'networkx'

# %%
import networkx as nx

# %%
H = nx.Graph()

# %%
G.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
G.edges()
# Out:
# EdgeView([(1, 2), (1, 6), (2, 3), (3, 4), (4, 5)])

# %%
import matplotlib.pyplot as plt

# %%
nx.draw(G)

# %%
nx.draw(G,with_labels = 1)

# %%
Z=nx.Graph()

# %%
Z.add_node(1)
Z.add_node(2)
Z.add_node(3)
Z.add_node(4)
Z.add_node(5)
Z.add_node(6)

# %%
Z.nodes()
# Out:
# NodeView((1, 2, 3, 4, 5, 6))

# %%
Z.add_edge(1,2)
Z.add_edge(2,3)
Z.add_edge(2,4)
Z.add_edge(2,5)
Z.add_edge(2,6)

# %%
Z.edges()
# Out:
# EdgeView([(1, 2), (2, 3), (2, 4), (2, 5), (2, 6)])

# %%
nx.draw(Z)

# %%
nx.draw(Z, with_labels =1)

# %%
nx.draw(Z,with_labels = 1,node_color = 'g')

# %%
k = nx.complete_graph(5)

# %%
nx.draw(k)

# %%
l = nx.complete_graph(25)

# %%
nx.draw(l)

# %%
m = nx.complete_graph(70)

# %%
nx.draw(m)

# %%
pos = nx.circular_layout(m)

# %%
nx.draw(m,pos)

# %%
nx.draw_circular(m)

# %%
nx.draw_spring(m)

# %%
nx.draw_random(m)

# %%
nx.draw_spectral(m)

# %%
m.order()
# Out:
# 70

# %%
m.size()
# Out:
# 2415

# %%
nx.is_graphical?

# %%
l=[2,2,2]

# %%
nx.is_graphical(l)
# Out:
# True

# %%
l=[2,2,1]

# %%
nx.is_graphical(l)
# Out:
# False

# %%
l = [5,5,3,3,2,2,2]
